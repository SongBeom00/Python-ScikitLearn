# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('seaborn-v0_8-whitegrid')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

noise = np.random.rand(100,1)
X = sorted(10 * np.random.rand(100,1)) + noise
y = sorted(10 * np.random.rand(100))


plt.scatter(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(f'선형 회귀 가중치 {model.coef_}') # 기울기
print(f'선형 회귀 편향 {model.intercept_}') # y절편
# Out:
# 선형 회귀 가중치 [1.0062296]
# 선형 회귀 편향 -0.7217863178421915

# %%
print(f"학습 데이터 점수 :{model.score(X_train,y_train)}")
print(f'평가 데이터 점수 :{model.score(X_test,y_test)}')
# Out:
# 학습 데이터 점수 :0.9838843091256382
# 평가 데이터 점수 :0.974748687797311

# %%
predict = model.predict(X_test)
plt.scatter(X_test,y_test)
plt.plot(X_test,predict,color='r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 predict = model.predict(X_test)
#       2 plt.scatter(X_test,y_test)
#       3 plt.plot(X_test,predict,color='r')
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:370, in LinearModel._decision_function(self, X)
#     367 check_is_fitted(self)
#     369 X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 370 return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:193, in safe_sparse_dot(a, b, dense_output)
#     191         ret = np.dot(a, b)
#     192 else:
# --> 193     ret = a @ b
#     195 if (
#     196     sparse.issparse(a)
#     197     and sparse.issparse(b)
#     198     and dense_output
#     199     and hasattr(ret, "toarray")
#     200 ):
#     201     return ret.toarray()
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# 보스턴 주택 가격 데이터

# %%
from sklearn import datasets

X, y = datasets.fetch_openml('boston', return_X_y=True)

boston_df = pd.DataFrame(X)
# Out:
# C:\Users\kjb00\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:303: UserWarning: Multiple active versions of the dataset matching the name boston exist. Versions may be fundamentally different, returning version 1.
#   warn(
# C:\Users\kjb00\anaconda3\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
boston_df['MEDV'] = y
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# std      2.105710  168.537116    2.164946   91.294864    7.141062    9.197104
# min      1.129600  187.000000   12.600000    0.320000    1.730000    5.000000
# 25%      2.100175  279.000000   17.400000  375.377500    6.950000   17.025000
# 50%      3.207450  330.000000   19.050000  391.440000   11.360000   21.200000
# 75%      5.188425  666.000000   20.200000  396.225000   16.955000   25.000000
# max     12.126500  711.000000   22.000000  396.900000   37.970000   50.000000

# %%
for i,col in enumerate(boston_df.columns) :
    plt.figure(figsize=(8,4))
    plt.plot(boston_df[col])
    plt.title(col)
    plt.xlabel('Town')

# %%
for i,col in enumerate(boston_df.columns) :
    plt.figure(figsize=(8,4))
    plt.scatter(boston_df[col],boston_df['MEDV'])
    plt.title(col)
    plt.xlabel('Town')
    plt.ylabel('MEDV')

# %%
import seaborn as sns

sns.pairplot(boston_df)

# %% [markdown]
# 보스턴 주택 가격에 대한 선형 회귀

# %%
model = LinearRegression()
